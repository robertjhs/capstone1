# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

# %%
ls
# Out:
# country_info.ipynb  data/  ethicars.ipynb  images/  README.md

# %%
df = pd.read_csv('data/countryInfo.csv')

# %%
df.head()
# Out:
#   ISO ISO3  ISO+AC0-Numeric fips               Country           Capital  \
# 0  AD  AND               20   AN               Andorra  Andorra la Vella
# 1  AE  ARE              784   AE  United Arab Emirates         Abu Dhabi
# 2  AF  AFG                4   AF           Afghanistan             Kabul
# 3  AG  ATG               28   AC   Antigua and Barbuda        St. John's
# 4  AI  AIA              660   AV              Anguilla        The Valley
#
#    Area(in sq km)  Population Continent  tld  ... Unnamed: 44 Unnamed: 45  \
# 0           468.0       84000        EU  .ad  ...         NaN         NaN
# 1         82880.0     4975593        AS  .ae  ...         NaN         NaN
# 2        647500.0    29121286        AS  .af  ...         NaN         NaN
# 3           443.0       86754       NaN  .ag  ...         NaN         NaN
# 4           102.0       13254       NaN  .ai  ...         NaN         NaN
#
#   Unnamed: 46 Unnamed: 47 Unnamed: 48 Unnamed: 49 Unnamed: 50 Unnamed: 51  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 54 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ISO                 251 non-null    object
#  1   ISO3                252 non-null    object
#  2   ISO+AC0-Numeric     252 non-null    int64
#  3   fips                249 non-null    object
#  4   Country             252 non-null    object
#  5   Capital             247 non-null    object
#  6   Area(in sq km)      251 non-null    float64
#  7   Population          252 non-null    int64
#  8   Continent           211 non-null    object
#  9   tld                 249 non-null    object
#  10  CurrencyCode        251 non-null    object
#  11  CurrencyName        251 non-null    object
#  12  Phone               247 non-null    object
#  13  Postal Code Format  159 non-null    object
#  14  Postal Code Regex   156 non-null    object
# ...
